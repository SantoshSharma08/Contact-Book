# %%
# In this project which is CONTACT BOOK we can create,view,search,update,delete all contacts  
# The main modules i will use Dictionary,Loops,Conditional Statements,Formated Strings and Input Statements.

# EMPTY DICTIONARY
contacts = {}

while True:
    print('\ncontact Book App')
    print('1. create contact')
    print('2. view contact')
    print('3. update contact')
    print('4. Delete contact')
    print('5. search contact')
    print('6. count contact')
    print('7. Exit')

    choice = input('enter your choice = ')

    if choice == '1' : 
        name= input('enter your name = ')
        if name in contacts:
            print(f'contact name {name} already exists!')

        else:
            address = input('Enter address = ' )
            email = input('Enter email = ')
            mobile = input('Enter mobile number =')
            contacts[name] = {'address':address, 'email':email, 'mobile':mobile}
            print(f'contact name {name} has been created successfully!')


    elif choice == '2':
        name = input('enter contact name to view = ')
        if name in contacts:
            contact = contacts[name]
            print(f'Name: {name},address:{address}, Mobile Number:{mobile}')

        else:
            print('contact Not found!')



    elif  choice == '3':
        name = input('Enter name to update contact = ' )
        if name in contacts:
            address = input('Enter updated address = ')
            email = input('Enter updated email = ')
            mobile = input('Enter updated mobile number = ')
            contacts[name] = {'address':address, 'email':email, 'mobile':mobile}

        else:
            print('contact not found!')


    elif choice == '4':
        name = input('Enter contact name to delete')
        if name in contacts:
            del contacts[name]
            print(f'contact name {name} has been deleted successfully!')

        else:
            print('contact not found')

    elif choice == '5':
        search_name = input('Enter contact name to search = ' )
        found = False
        for name, contact in contacts.items():
            if search_name.lower() in name.lower():

                print(f'found - Name {name}, Address:{address}. Mobile Number:{mobile},Email:{email}')
                found = True

        
        if not found:
            print('no contact found with that name')


    elif choice == '6':
        print(f'Total contacts in your book : {len(contacts)}')



    elif choice == '7':
        print('Goodbye ......... closing the program')
        break


    else:
        print('Invalid input')
# Out:
# contact Book App
# 1. create contact
# 2. view contact
# 3. update contact
# 4. Delete contact
# 5. search contact
# 6. count contact
# 7. Exit
# enter your choice = 1
# enter your name = toshi
# Enter address = Haryana
# Enter email = toshi01@gmail.com
# Enter mobile number =9893405680
# contact name toshi has been created successfully!
#
# contact Book App
# 1. create contact
# 2. view contact
# 3. update contact
# 4. Delete contact
# 5. search contact
# 6. count contact
# 7. Exit
# enter your choice = 2
# enter contact name to view = toshi
# Name: toshi,address:Haryana, Mobile Number:9893405680
#
# contact Book App
# 1. create contact
# 2. view contact
# 3. update contact
# 4. Delete contact
# 5. search contact
# 6. count contact
# 7. Exit
